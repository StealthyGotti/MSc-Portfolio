# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.signal import convolve

# %% [markdown]
# Local Polynomial Approximation
# -------------------------------
# Set the parameters

# %%
# maximum degree of polynomial used for fitting
N = 2

# filter size
M = 51

# large M, small N -> a lot of bias when frequency increases
#N = 2
#M = 51

# large M, large N -> smaller bias than before, but a lot of variance in smooth regions
# N = 7
# M = 51

# small M, small N -> smaller bias everywhere, higher variance
# N = 2
# M = 5

# M small, M = N,  -> smaller bias than before, higher variance than before
N = 5
N = M

# %% [markdown]
# Generate synthetic signal signal

# %%
LENGHT = 1000

ty = np.linspace(0, 1, LENGHT)
y = np.sin(2 / (ty + 0.05))

#  noise standard deviation
sigma = 0.1

# noisy signal
s = y + sigma*np.random.normal(size=LENGHT)

# %%
plt.figure()
plt.plot(ty, s, 'r.')
plt.plot(ty, y, 'k--', linewidth=2)
plt.grid()
plt.legend(['noisy', 'original'])
plt.title('Input Signal')
# Out:
# Text(0.5, 1.0, 'Input Signal')

# %% [markdown]
# Define the matrix T containing the polynomials sampled over the window

# %%
t = np.linspace(-1, 1, M)
T = np.zeros((M, N+1))
for l in range(N+1):
    T[:, l] = t**l

# %% [markdown]
# Look at the matrix T, the columns correspond to polynomials sampled over the interval [0,1]

# %%
plt.figure()
leg = []
for l in range(N+1):
    plt.plot(t, T[:, l])
    leg.append(f't^{l:d}')
plt.legend(leg)

# %% [markdown]
# Construct the LPA kernel

# %%
# comput the qr decomposition of WT
# since T has more rows than columns, then qr computes only the first N + 1 columns of Q and the first N + 1 rows of R.
Q, R = np.linalg.qr(T)

# select the central row of W2Qtilde
row = Q[int((M-1)/2), :]

# compute the kernel
g = Q @ row

# flipping, since it is used in convolution
g = np.flip(g)

# %%
plt.figure()
plt.plot(g, 'rs', linewidth=3)
plt.title(f'M = {M:d}, N = {N:d}')
# Out:
# Text(0.5, 1.0, 'M = 51, N = 51')

# %% [markdown]
# Filtering

# %%
shat = convolve(s, g, mode='same')

# %%
plt.figure(figsize=(10,10))
plt.plot(ty, s, 'r.')
plt.plot(ty, y, 'k--', linewidth=3)
plt.plot(ty, shat, 'm-', linewidth=3)
plt.grid()
plt.legend(['noisy', 'original', 'LPA estimate'])
plt.title(f'M = {M:d}, N = {N:d}')
# Out:
# Text(0.5, 1.0, 'M = 51, N = 51')

# %% [markdown]
# Weighted LPA
# --------------
# Set the parameters

# %%
# maximum degree of polynomial used for fitting
N = 1

# filter size
M = 53

# half filter size
HFS = int((M-1)/2)

# set the weights. Here weights simply define the window size
w = np.zeros(M)

# centered kernel
wc = w.copy()
wc[int(HFS/2):-int(HFS/2)] = 1

# left kernel
wl = w.copy()
wl[:HFS+1] = 1

# right kernel
wr = w.copy()
wr[-HFS-1:] = 1

# %%
fig, ax = plt.subplots(3, 1, figsize=(10,10))
ax[0].plot(wc, 'rs', linewidth=3)
ax[0].set_title('centered weights')
ax[0].grid()
ax[1].plot(wl, 'bs', linewidth=3)
ax[1].set_title('left weights')
ax[1].grid()
ax[2].plot(wr, 'ms', linewidth=3)
ax[2].set_title('right weights')
ax[2].grid()

# %% [markdown]
# Build the weight matrix

# %%
# select a single weight to be used in what follows
w = wc

# generate the inverse of weights
winv = 1.0/w

# set to zero weights that are inf
winv[np.isinf(winv)] = 0

# define the weight matrix
W = np.diag(w)
Winv = np.diag(winv)
# Out:
# /tmp/ipykernel_8076/390297690.py:5: RuntimeWarning: divide by zero encountered in divide
#   winv = 1.0/w

# %% [markdown]
# Generate synthetic signal signal

# %%
LENGHT = 1000

# clean signal
ty = np.linspace(0, 1, LENGHT)
y =  8*ty**2 - 2*ty + 2;
y[LENGHT//2 : LENGHT] = y[LENGHT//2 : LENGHT] + 7;

#  noise standard deviation
sigma = 0.2

# noisy signal
s = y + sigma*np.random.normal(size=LENGHT)

# %%
plt.figure()
plt.plot(ty, s, 'r.')
plt.plot(ty, y, 'k--', linewidth=2)
plt.grid()
plt.legend(['noisy', 'original'])
plt.title('Input Signal')
# Out:
# Text(0.5, 1.0, 'Input Signal')

# %% [markdown]
# Define the matrix T containing the polynomials sampled over the window

# %%
t = np.linspace(-1, 1, M)
T = np.zeros((M, N+1))
for l in range(N+1):
    T[:, l] = t**l

# %% [markdown]
# Construct the LPA kernel

# %%
# comput the qr decomposition of WT
# since T has more rows than columns, then qr computes only the first N + 1 columns of Q and the first N + 1 rows of R.
Q, R = np.linalg.qr(W@T)

#  define Qtilde
Qtilde = Winv @ Q

# adjust Qtilde with the  weights matrix squared.
W2Qtilde = W @ W @ Qtilde

# select the central row of W2Qtilde
row = W2Qtilde[int((M-1)/2), :]

# compute the kernel
g = Qtilde @ row

# flipping, since it is used in convolution
g = np.flip(g)

# %%
plt.figure()
plt.plot(g, 'rs', linewidth=3)
plt.title(f'filter M = {M:d}, N = {N:d}')
# Out:
# Text(0.5, 1.0, 'filter M = 53, N = 1')

# %% [markdown]
# Filtering

# %%
shat = convolve(s, g, mode='same')

# %%
plt.figure()
plt.plot(ty, s, 'r.')
plt.plot(ty, y, 'k--', linewidth=3)
plt.plot(ty, shat, 'm-', linewidth=3)
plt.grid()
plt.legend(['noisy', 'original', 'LPA estimate'])
plt.title(f'M = {M:d}, N = {N:d}')
# Out:
# Text(0.5, 1.0, 'M = 53, N = 1')

# %% [markdown]
# Modify the code to use the central, left and right kernels

# %%
# kernels dictionary
weights_dict = {'central': wc, 'left': wl, 'right': wr}
estimates = {}

for name, w in weights_dict.items():
    winv = 1.0 / w
    winv[np.isinf(winv)] = 0

    W = np.diag(w)
    Winv = np.diag(winv)

    Q, R = np.linalg.qr(W @ T)
    Qtilde = Winv @ Q
    W2Qtilde = W @ W @ Qtilde

    row = W2Qtilde[int((M-1)/2), :]
    g = Qtilde @ row
    g = np.flip(g)

    estimates[name] = convolve(s, g, mode='same')

# plot
plt.figure(figsize=(12, 8))
plt.plot(ty, s, 'r.', alpha=0.3, label='noisy')
plt.plot(ty, y, 'k--', linewidth=2, label='original')

colors = {'central': 'm-', 'left': 'b-', 'right': 'g-'}
for name, shat_w in estimates.items():
    plt.plot(ty, shat_w, colors[name], linewidth=2, label=f'{name} estimate')

plt.grid()
plt.legend()
plt.title(f'Weighted LPA: M = {M}, N = {N}')
plt.show()
# Out:
# /tmp/ipykernel_8076/2731305863.py:6: RuntimeWarning: divide by zero encountered in divide
#   winv = 1.0 / w
